# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
d1=pd.read_csv(r'C:\Users\Lingraj\Desktop\recordings\mainboot\Assignment\Task4\college_1.csv')
d2=pd.read_csv(r'C:\Users\Lingraj\Desktop\recordings\mainboot\Assignment\Task4\college_2.csv')
result = pd.concat([d1,d2])         #gets them as a single dataframe
result
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [raw]
# if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df=result[result['CodeKata Score']>15000]
df.to_csv('Exceeded_expectations.csv',index=False)
df=result[result['CodeKata Score'].between(10000,15000)]
df.to_csv('Reached_expectations.csv',index=False)
df=result[result['CodeKata Score'].between(7000,10000)]
df.to_csv('Needs_Improvement.csv',index=False)
df=result[result['CodeKata Score']<7000]
df.to_csv('Unsatisfactory.csv',index=False)

# %%
k=int(input("1.Exceeded expectations\n2.Reached expectations\n3.Needs Improvement\n4.Unsatisfactory\n"))
if k==1:
    h=pd.read_csv("Exceeded_expectations.csv")
    print(h)
elif k==2:
    h=pd.read_csv("Reached_expectations.csv")
    print(h)
elif k==3:
    h=pd.read_csv("Needs_Improvement.csv")
    print(h)
elif k==4:
    h=pd.read_csv("Unsatisfactory.csv")
    print(h)
# Out:
# 1.Exceeded expectations
# 2.Reached expectations
# 3.Needs Improvement
# 4.Unsatisfactory
# 4
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        J.SUGANTHI    27.0  50.00               5860            5860
# 1      thamizhpaana    29.0   0.00               5500            5500
# 2   Iyappan Samiraj    50.0  24.00               5400            5400
# 3      Ponniyamma.R   100.0  11.25               5380            5380
# 4         SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 88    praveen raj j    24.0   0.00               2380            2380
# 89       AMARNATH D    -1.0  12.00               1890            1890
# 90             bala    32.0   0.00               1720            1720
# 91             XY Z    -1.0  -1.00                  0               0
# 92        Hariharan    -1.0  -1.00                  0               0
#
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
print("Average of Previous week geekions:",result['Previous Geekions'].mean())
print("Average of CodeKata Score:",result['CodeKata Score'].mean())
# Out:
# Average of Previous week geekions: 3842.3529411764707
# Average of CodeKata Score: 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
print("Number of students participated:",result.shape[0])
# Out:
# Number of students participated: 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
print("Average completion of {} course:", result['python'].mean())
print("Average completion of my_sql course:", result['mysql'].mean())
print("Average completion of python english course:", result['python_en'].mean())
print("Average completion of computational thinking course:", result['computational_thinking'].mean())
# Out:
# Average completion of {} course: 54.35294117647059
# Average completion of my_sql course: 23.5
# Average completion of python english course: 29.65714285714286
# Average completion of computational thinking course: 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
result.sort_values(by=['CodeKata Score', 'Name'], ascending=[False, True]).head(3)['Name']
# Out:
# 0      A.Dharani
# 1    V.JEEVITHA
# 2    HEMAVATHI.R
# Name: Name, dtype: object

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
result.sort_values(by=['Previous Geekions', 'Name'], ascending=[False, True]).head(3)['Name']
# Out:
# 0      A.Dharani
# 1    V.JEEVITHA
# 2    HEMAVATHI.R
# Name: Name, dtype: object

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import matplotlib.pyplot as plt
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]
explode=[0, 0.1, 0]
plt.pie(list(result.groupby('Department')['CodeKata Score'].mean()), labels=list(result['Department'].unique()), explode=explode, colors=colors, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
dg=result.loc[:,['Name','Department','CodeKata Score']]
cs = dg[dg['Department']=='Computer Science and Engineering']
ec = dg[dg['Department']=='Electronics and Communication Engineering']
ee = dg[dg['Department']=='Electronics and Electrical Engineering']

# %%
fig = plt.figure(figsize=(12, 12))
plt.barh(cs['Name'],cs['CodeKata Score'])
plt.title('Computer Science and Engineering')
plt.show()

# %%
fig = plt.figure(figsize=(12, 12))
plt.barh(ec['Name'],ec['CodeKata Score'])
plt.title('Electronics and Communication Engineering')
plt.show()

# %%
fig = plt.figure(figsize=(12, 12))
plt.barh(ee['Name'],ee['CodeKata Score'])
plt.title('Electronics and Electrical Engineering')
plt.show()
